# %% [markdown]
# # 🧠 Alzheimer's MRI Data Visualization and Exploration
#
# <div style=" padding: 20px; border-radius: 8px; border-left: 5px solid #4285f4; margin-bottom: 20px;">
# <h3 style="margin-top: 0; color: #4285f4;">Overview</h3>
# <p>This notebook provides tools for visualizing and exploring MRI data for Alzheimer's disease detection. It includes functions for loading, displaying, and analyzing brain MRI images.</p>
# </div>

# %% [markdown]
# ## 📚 Import Libraries
#
# First, let's import the necessary libraries for our analysis.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import seaborn as sns

plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette("viridis")
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['axes.titlesize'] = 16
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# %% [markdown]
# ## 📊 Class Distribution Visualization
#
# Let's visualize the distribution of classes in our dataset.

# %%
# import the data_distribution function from the visualization module
from src.utils.visualization import data_distribution

class_counts = data_distribution()
# Out:
# 2025-03-22 12:13:03 | src_utils_visualization | INFO | Data directory found at: D:\03. Projects\End_To_End_Projects\End_to_end_Alzheimer_image_classification\Data\raw
# 2025-03-22 12:13:03 | src_utils_visualization | INFO | Found 4 classes: Mild Dementia, Moderate Dementia, Non Demented, Very mild Dementia

# %% [markdown]
# ## 🖼️ Sample Images Visualization
#
# <div style="background-color:rgb(74, 68, 59); padding: 15px; border-radius: 8px; border-left: 5px solid #ff9800; margin-bottom: 20px;">
# <h3 style="margin-top: 0; color: #e65100;">MRI Sample Visualization</h3>
# <p>Now let's visualize some sample images from each class to understand the visual characteristics.</p>
# </div>

# %%
from src.utils.visualization import get_sample_images, display_multiple_images

# %%
classes = list(class_counts.keys())

if len(classes) > 0:
    samples = get_sample_images(classes)
    
    # Display samples from each class
    for cls, image_files in samples.items():
        print(f"\n📊 Displaying sample images from class: {cls}")
        if len(image_files) > 0:
            display_multiple_images(image_files)
        else:
            print("  No images found for this class.")
else:
    print("⚠️ No class data available. Please run the previous cells with valid data path.")
# Out:
# 2025-03-22 12:13:20 | src_utils_visualization | INFO | Displaying 4 images
# 2025-03-22 12:13:20 | src_utils_visualization | INFO | Loaded image D:\03. Projects\End_To_End_Projects\End_to_end_Alzheimer_image_classification\Data\raw\Mild Dementia\OAS1_0028_MR1_mpr-1_154.jpg with shape (248, 496)
# 2025-03-22 12:13:20 | src_utils_visualization | INFO | Loaded image D:\03. Projects\End_To_End_Projects\End_to_end_Alzheimer_image_classification\Data\raw\Mild Dementia\OAS1_0052_MR1_mpr-4_101.jpg with shape (248, 496)
# 2025-03-22 12:13:20 | src_utils_visualization | INFO | Loaded image D:\03. Projects\End_To_End_Projects\End_to_end_Alzheimer_image_classification\Data\raw\Mild Dementia\OAS1_0052_MR1_mpr-1_132.jpg with shape (248, 496)
# 2025-03-22 12:13:20 | src_utils_visualization | INFO | Loaded image D:\03. Projects\End_To_End_Projects\End_to_end_Alzheimer_image_classification\Data\raw\Mild Dementia\OAS1_0268_MR1_mpr-3_143.jpg with shape (248, 496)
# ...

# %% [markdown]
# ## Next Steps
#
# 1. **Preprocessing**: Implement image preprocessing techniques:
#    - Standardization/normalization
#    - Skull stripping
#    - Noise reduction
#
# 2. **Feature Engineering**: Extract meaningful features from MRI images
#
# 3. **Model Development**: Develop CNN models for Alzheimer's detection
#
# 4. **Evaluation**: Evaluate model performance and clinical relevance
